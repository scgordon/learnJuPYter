# %%
import pandas as pd
import matplotlib.pyplot as plt
from bokeh.charts import output_notebook, output_file, show, Bar, Scatter, Histogram, TimeSeries
from bokeh.plotting import figure
from bokeh.models import Range1d, HoverTool, ResizeTool
output_notebook()
# Out:
# /Applications/anaconda/lib/python3.6/site-packages/matplotlib/font_manager.py:280: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   'Matplotlib is building the font cache using fc-list. '
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="c56724a3-fe9f-4687-b63f-eb07690ef20a">Loading BokehJS ...</span>
#     </div>

# %%
data = pd.read_csv('../ConceptMining/data/NASA/GHRC_ISO_data2.csv')

# %%
data
# Out:
#       Collection Dialect         Record  \
# 0           GHRC     ISO     lohrac.xml
# 1           GHRC     ISO     lohrac.xml
# 2           GHRC     ISO     lohrac.xml
# 3           GHRC     ISO     lohrac.xml
# 4           GHRC     ISO     lohrac.xml
# 5           GHRC     ISO     lohrac.xml
# 6           GHRC     ISO     lohrac.xml
# 7           GHRC     ISO     lohrac.xml
# 8           GHRC     ISO     lohrac.xml
# 9           GHRC     ISO     lohrac.xml
# 10          GHRC     ISO     lohrac.xml
# 11          GHRC     ISO     lohrac.xml
# 12          GHRC     ISO     lohrac.xml
# 13          GHRC     ISO     lohrac.xml
# 14          GHRC     ISO     lohrac.xml
# 15          GHRC     ISO     lohrac.xml
# 16          GHRC     ISO     lohrac.xml
# 17          GHRC     ISO     lohrac.xml
# 18          GHRC     ISO     lohrac.xml
# 19          GHRC     ISO     lohrac.xml
# 20          GHRC     ISO     lohrac.xml
# 21          GHRC     ISO     lohrac.xml
# ...

# %%
Theme_Keyword = data[data.Concept == 'Theme Keyword']

# %%
Theme_Keyword
# Out:
#       Collection Dialect           Record        Concept  \
# 882         GHRC     ISO       lohrac.xml  Theme Keyword
# 1799        GHRC     ISO       lohrfc.xml  Theme Keyword
# 2716        GHRC     ISO       lohrmc.xml  Theme Keyword
# 3633        GHRC     ISO       lolrac.xml  Theme Keyword
# 4550        GHRC     ISO     lolracts.xml  Theme Keyword
# 5467        GHRC     ISO      lolradc.xml  Theme Keyword
# 6384        GHRC     ISO       lolrdc.xml  Theme Keyword
# 7301        GHRC     ISO       lolrfc.xml  Theme Keyword
# 8218        GHRC     ISO      lolrmts.xml  Theme Keyword
# 9135        GHRC     ISO       lolrts.xml  Theme Keyword
# 10543       GHRC     ISO        msut2.xml  Theme Keyword
# 10544       GHRC     ISO        msut2.xml  Theme Keyword
# 10545       GHRC     ISO        msut2.xml  Theme Keyword
# 10546       GHRC     ISO        msut2.xml  Theme Keyword
# 11951       GHRC     ISO      msut2lt.xml  Theme Keyword
# ...

# %%
p = Bar(data, 'Concept', title="testit")

output_file("bar.html")

show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="4b1ecc0a-caef-4612-afa4-11d5b9f26ddb"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
# ...

# %%
grp = Theme_Keyword.groupby('Content')

# %%
grp['Record'].describe().unstack()
# Out:
#                                                    count unique  \
# Content
# EARTH SCIENCE>ATMOSPHERE>ATMOSPHERIC ELECTRICIT...    10     10
# EARTH SCIENCE>ATMOSPHERE>ATMOSPHERIC TEMPERATUR...     3      3
# EARTH SCIENCE>ATMOSPHERE>ATMOSPHERIC TEMPERATUR...     3      3
# EARTH SCIENCE>ATMOSPHERE>ATMOSPHERIC WATER VAPO...     1      1
# EARTH SCIENCE>ATMOSPHERE>ATMOSPHERIC WATER VAPO...    33     33
# EARTH SCIENCE>ATMOSPHERE>ATMOSPHERIC WINDS>SURF...    32     32
# EARTH SCIENCE>ATMOSPHERE>PRECIPITATION>RAIN>NON...    32     32
# EARTH SCIENCE>SPECTRAL/ENGINEERING>INFRARED WAV...     3      3
# EARTH SCIENCE>SPECTRAL/ENGINEERING>MICROWAVE>BR...     3      3
#
#                                                                 top freq
# Content
# EARTH SCIENCE>ATMOSPHERE>ATMOSPHERIC ELECTRICIT...       lolrdc.xml    1
# EARTH SCIENCE>ATMOSPHERE>ATMOSPHERIC TEMPERATUR...      msut2lt.xml    1
# EARTH SCIENCE>ATMOSPHERE>ATMOSPHERIC TEMPERATUR...      msut2lt.xml    1
# ...

# %%
p = Bar(Theme_Keyword, 'Content', plot_width=2400, plot_height=800, title="testit", legend=False)

output_file("bar2.html")

show(p)
# Out:
# INFO:bokeh.core.state:Session output file 'bar2.html' already exists, will be overwritten.
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="e56d5790-14d5-4ef6-96c0-b196e616243d"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
# ...
