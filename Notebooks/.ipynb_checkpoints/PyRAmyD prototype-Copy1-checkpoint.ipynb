# %% [markdown]
# ## First Goal: select data interactively

# %% [markdown]
# ### The purpose of this notebook is to read in a csv that the user selects by selecting the organization and dialect and collection. It's a way to learn how to create dropdowns that interact with each other.

# %%
import pandas as pd
import os
from os import walk
import numpy as np
from ipykernel import kernelapp as app
from __future__ import print_function
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets
from ipywidgets import Button, Layout
from glob import glob

# %% [markdown]
# ### Read in csv for dialects and for recommendations. RecTag is not a well-formed CSV. May take advantage of John Farley's early work now that I can finally start to understand it.

# %%
ConceptsPresenceAbsenceDF= pd.read_csv('/Users/scgordon/ConceptMining/Tables/dialectTable/dialectContains.csv')

# %%
#RecommendationsDF= pd.read_csv('/Users/scgordon/ConceptMining/Tables/RecommendationsTable/RecTag.csv')

# %% [markdown]
# ### query the directory for subdirectory names, return them in a list.

# %%
Organizations = []
for (dirpath, dirnames, filenames) in walk('/Users/scgordon/ConceptMining/data/'):
    Organizations.extend(dirnames)
    break
Organizations
# Out:
# ['BCO-DMO',
#  'DataOne',
#  'IEDA',
#  'LTERthroughTime',
#  'NASA',
#  'NCAR',
#  'ORNL',
#  'USGS']

# %%
def OrganizationChoice(Organization):
    CollectionChoices=os.listdir(os.path.join('/Users/scgordon/ConceptMining/data',Organization))
    return CollectionChoices

# %%
def CollectionChoice(Collection):
    CollectionConceptsDF= pd.read_csv(os.path.join('/Users/scgordon/ConceptMining/data/', Organization, Collection))
    return CollectionConceptsDF

# %%
OrganizationChoice('NASA')
# Out:
# ['GES_DISC_DIF_data.csv',
#  'GHRC_DIF_data.csv',
#  'GHRC_ISO_data.csv',
#  'GHRC_ISO_data2.csv',
#  'LARC2_ISO_data.csv',
#  'LARC_DIF_data.csv',
#  'LARC_ISO_data.csv',
#  'NSIDC_DIF_data.csv',
#  'NSIDC_DIF_data1.xlsx',
#  'NSIDC_DIF_data2.xlsx',
#  'NSIDC_DIF_data3.xlsx',
#  'NSIDC_HopeThisWorks_RAD.xlsx',
#  'NSIDC_ISO_data.csv',
#  'NSIDC_ISO_data1.csv',
#  'NSIDC_ISO_data2.xlsx',
#  'NSIDC_ISO_data3.xlsx',
#  'NSIDC_ISO_data4.xlsx']

# %% [raw]
# interact(OrganizationChoice, Choice=Organizations)

# %% [markdown]
# ### Reading in the CSV containing the concept data.

# %%
interact(CollectionChoice, Collection=CollectionChoices)
# Out:
#      Collection Dialect           Record                Concept
# 0      GES_DISC     DIF  C1233768985.xml               Abstract
# 1      GES_DISC     DIF  C1233768985.xml               Abstract
# 2      GES_DISC     DIF  C1233768985.xml             Award Link
# 3      GES_DISC     DIF  C1233768985.xml             Award Link
# 4      GES_DISC     DIF  C1233768985.xml             Award Link
# 5      GES_DISC     DIF  C1233768985.xml             Award Link
# 6      GES_DISC     DIF  C1233768985.xml             Award Link
# 7      GES_DISC     DIF  C1233768985.xml             Award Link
# 8      GES_DISC     DIF  C1233768985.xml             Award Link
# 9      GES_DISC     DIF  C1233768985.xml             Award Link
# 10     GES_DISC     DIF  C1233768985.xml             Award Link
# 11     GES_DISC     DIF  C1233768985.xml             Award Link
# 12     GES_DISC     DIF  C1233768985.xml           Bounding Box
# 13     GES_DISC     DIF  C1233768985.xml           Bounding Box
# 14     GES_DISC     DIF  C1233768985.xml           Bounding Box
# 15     GES_DISC     DIF  C1233768985.xml           Bounding Box
# 16     GES_DISC     DIF  C1233768985.xml  Easternmost Longitude
# 17     GES_DISC     DIF  C1233768985.xml                  Email
# 18     GES_DISC     DIF  C1233768985.xml             First Name
# 19     GES_DISC     DIF  C1233768985.xml             Instrument
# 20     GES_DISC     DIF  C1233768985.xml             Instrument
# 21     GES_DISC     DIF  C1233768985.xml     Instrument Keyword
# 22     GES_DISC     DIF  C1233768985.xml     Instrument Keyword
# 23     GES_DISC     DIF  C1233768985.xml     Instrument Keyword
# 24     GES_DISC     DIF  C1233768985.xml     Instrument Keyword
# 25     GES_DISC     DIF  C1233768985.xml   Instrument Long Name
# 26     GES_DISC     DIF  C1233768985.xml  Instrument Short Name
# 27     GES_DISC     DIF  C1233768985.xml  Instrument Short Name
# 28     GES_DISC     DIF  C1233768985.xml                Keyword
# 29     GES_DISC     DIF  C1233768985.xml                Keyword
# ...         ...     ...              ...                    ...
# 1721   GES_DISC     DIF  C1243477383.xml          Theme Keyword
# 1722   GES_DISC     DIF  C1243477383.xml          Theme Keyword
# 1723   GES_DISC     DIF  C1243477383.xml          Theme Keyword
# 1724   GES_DISC     DIF  C1243477383.xml          Theme Keyword
# 1725   GES_DISC     DIF  C1243477383.xml          Theme Keyword
# 1726   GES_DISC     DIF  C1243477383.xml          Theme Keyword
# 1727   GES_DISC     DIF  C1243477383.xml          Theme Keyword
# 1728   GES_DISC     DIF  C1243477383.xml          Theme Keyword
# 1729   GES_DISC     DIF  C1243477383.xml          Theme Keyword
# 1730   GES_DISC     DIF  C1243477383.xml          Theme Keyword
# 1731   GES_DISC     DIF  C1243477383.xml          Theme Keyword
# 1732   GES_DISC     DIF  C1243477383.xml          Theme Keyword
# 1733   GES_DISC     DIF  C1243477383.xml          Theme Keyword
# 1734   GES_DISC     DIF  C1243477383.xml          Theme Keyword
# 1735   GES_DISC     DIF  C1243477383.xml          Theme Keyword
# 1736   GES_DISC     DIF  C1243477383.xml          Theme Keyword
# 1737   GES_DISC     DIF  C1243477383.xml          Theme Keyword
# 1738   GES_DISC     DIF  C1243477383.xml          Theme Keyword
# 1739   GES_DISC     DIF  C1243477383.xml          Theme Keyword
# 1740   GES_DISC     DIF  C1243477383.xml          Theme Keyword
# 1741   GES_DISC     DIF  C1243477383.xml          Theme Keyword
# 1742   GES_DISC     DIF  C1243477383.xml          Theme Keyword
# 1743   GES_DISC     DIF  C1243477383.xml          Theme Keyword
# 1744   GES_DISC     DIF  C1243477383.xml          Theme Keyword
# 1745   GES_DISC     DIF  C1243477383.xml          Theme Keyword
# 1746   GES_DISC     DIF  C1243477383.xml          Theme Keyword
# 1747   GES_DISC     DIF  C1243477383.xml          Theme Keyword
# 1748   GES_DISC     DIF  C1243477383.xml          Theme Keyword
# 1749   GES_DISC     DIF  C1243477383.xml          Theme Keyword
# 1750   GES_DISC     DIF  C1243477383.xml  Westernmost Longitude
#
# [1751 rows x 4 columns]
# <function __main__.CollectionChoice>

# %%
Organization='NASA'

# %%
def PropertyTypeTable(PropertyType):
    ProperTable = BBobjectsDF[BBobjectsDF.PropertyType.str.contains( PropertyType )]
    return ProperTable
