# %% [markdown]
# ## First Goal: select data interactively

# %% [markdown]
# ### The purpose of this notebook is to read in a csv that the user selects by selecting the organization and dialect and collection. It's a way to learn how to create dropdowns that interact with each other.

# %%
import pandas as pd
import os
from os import walk
import numpy as np
from ipykernel import kernelapp as app
from __future__ import print_function
from ipywidgets import *
import ipywidgets as widgets
#from ipywidgets import Button, Layout
#from glob import glob

# %% [markdown]
# ### Read in csv for dialects and for recommendations. RecTag is not a well-formed CSV. May take advantage of John Farley's early work now that I can finally start to understand it.

# %%
ConceptsPresenceAbsenceDF= pd.read_csv('/Users/scgordon/ConceptMining/Tables/dialectTable/dialectContains.csv')

# %%
#RecommendationsDF= pd.read_csv('/Users/scgordon/ConceptMining/Tables/RecommendationsTable/RecTag.csv')

# %% [markdown]
# ### query the directory for subdirectory names, return them in a list.

# %%
Organizations = []
for (dirpath, dirnames, filenames) in walk('/Users/scgordon/ConceptMining/data/'):
    Organizations.extend(dirnames)
    break
Organizations
# Out:
# ['BCO-DMO',
#  'DataOne',
#  'IEDA',
#  'LTERthroughTime',
#  'NASA',
#  'NCAR',
#  'ORNL',
#  'USGS']

# %% [markdown]
# ### Create a function to populate a variable used to populate the list for the collection dropdown

# %%
def OrganizationChoices(Organization):
    global OrganizationChoice
    global Collections
    OrganizationChoice=os.path.join('/Users/scgordon/ConceptMining/data',Organization)
    Collections=os.listdir(OrganizationChoice)
    return Collections

# %%
interactive(OrganizationChoices, Organization=Organizations)
# Out:
# ['CDL_CSDGM_data.csv',
#  'CLOEBIRD_EML_data.csv',
#  'Dryad_Dryad_data.csv',
#  'EDACGSTORE_CSDGM_data.csv',
#  'EDORA_Mercury_data.csv',
#  'ESA_EML_data.csv',
#  'GLEON_EML_data.csv',
#  'GOA_EML_data.csv',
#  'IARC_Onedcx_data.csv',
#  'IOE_EML_data.csv',
#  'KNB_EML_data.csv',
#  'KUBI_EML_data.csv',
#  'LTER_EML_data.csv',
#  'LTER_EUROPE_EML_data.csv',
#  'NMEPSCOR_CSDGM_data.csv',
#  'ONEShare_EML_data.csv',
#  'ORNLDAAC_Mercury_data.csv',
#  'PISCO_EML_data.csv',
#  'RGD_Mercury_data.csv',
#  'SANPARKS_EML_data.csv',
#  'SEAD_CSDGM_data.csv',
#  'TERN_EML_data.csv',
#  'TFRI_EML_data.csv',
#  'US_MPC_Onedcx_data.csv',
#  'USANPN_EML_data.csv',
#  'USGSCSAS_BDP_data.csv',
#  'USGSCSAS_CSDGM_data.csv']

# %%
def CollectionChoices(Collection):
    global CollectionConceptsDF
    CollectionConceptsDF= pd.read_csv(os.path.join(OrganizationChoice, Collection))
    return CollectionConceptsDF

# %%
interactive(CollectionChoices, Collection=Collections)
# Out:
#      Collection Dialect              Record                          Concept
# 0         Dryad   Dryad  00759-metadata.xml                         Abstract
# 1         Dryad   Dryad  00759-metadata.xml                           Author
# 2         Dryad   Dryad  00759-metadata.xml                           Author
# 3         Dryad   Dryad  00759-metadata.xml                           Author
# 4         Dryad   Dryad  00759-metadata.xml                           Author
# 5         Dryad   Dryad  00759-metadata.xml              Author / Originator
# 6         Dryad   Dryad  00759-metadata.xml              Author / Originator
# 7         Dryad   Dryad  00759-metadata.xml              Author / Originator
# 8         Dryad   Dryad  00759-metadata.xml              Author / Originator
# 9         Dryad   Dryad  00759-metadata.xml                     Embargo Date
# 10        Dryad   Dryad  00759-metadata.xml                          Keyword
# 11        Dryad   Dryad  00759-metadata.xml                          Keyword
# 12        Dryad   Dryad  00759-metadata.xml                          Keyword
# 13        Dryad   Dryad  00759-metadata.xml                          Keyword
# 14        Dryad   Dryad  00759-metadata.xml                          Keyword
# 15        Dryad   Dryad  00759-metadata.xml                          Keyword
# 16        Dryad   Dryad  00759-metadata.xml                          Keyword
# 17        Dryad   Dryad  00759-metadata.xml                Lineage Statement
# 18        Dryad   Dryad  00759-metadata.xml                Lineage Statement
# 19        Dryad   Dryad  00759-metadata.xml                Parent Identifier
# 20        Dryad   Dryad  00759-metadata.xml                 Publication Date
# 21        Dryad   Dryad  00759-metadata.xml      Related Resource Identifier
# 22        Dryad   Dryad  00759-metadata.xml           Resource Creation Date
# 23        Dryad   Dryad  00759-metadata.xml  Resource Creation/Revision Date
# 24        Dryad   Dryad  00759-metadata.xml              Resource Identifier
# 25        Dryad   Dryad  00759-metadata.xml              Resource Identifier
# 26        Dryad   Dryad  00759-metadata.xml                 Resource Lineage
# 27        Dryad   Dryad  00759-metadata.xml                 Resource Lineage
# 28        Dryad   Dryad  00759-metadata.xml                   Resource Title
# 29        Dryad   Dryad  00759-metadata.xml                    Resource Type
# ...         ...     ...                 ...                              ...
# 8059      Dryad   Dryad  01008-metadata.xml              Resource Identifier
# 8060      Dryad   Dryad  01008-metadata.xml                 Resource Lineage
# 8061      Dryad   Dryad  01008-metadata.xml                 Resource Lineage
# 8062      Dryad   Dryad  01008-metadata.xml                   Resource Title
# 8063      Dryad   Dryad  01008-metadata.xml                    Resource Type
# 8064      Dryad   Dryad  01008-metadata.xml                           Rights
# 8065      Dryad   Dryad  01008-metadata.xml                 Taxonomic Extent
# 8066      Dryad   Dryad  01008-metadata.xml                 Taxonomic Extent
# 8067      Dryad   Dryad  01008-metadata.xml                 Taxonomic Extent
# 8068      Dryad   Dryad  04198-metadata.xml                         Abstract
# 8069      Dryad   Dryad  04198-metadata.xml                           Author
# 8070      Dryad   Dryad  04198-metadata.xml                           Author
# 8071      Dryad   Dryad  04198-metadata.xml                           Author
# 8072      Dryad   Dryad  04198-metadata.xml              Author / Originator
# 8073      Dryad   Dryad  04198-metadata.xml              Author / Originator
# 8074      Dryad   Dryad  04198-metadata.xml              Author / Originator
# 8075      Dryad   Dryad  04198-metadata.xml                     Embargo Date
# 8076      Dryad   Dryad  04198-metadata.xml                Lineage Statement
# 8077      Dryad   Dryad  04198-metadata.xml                Parent Identifier
# 8078      Dryad   Dryad  04198-metadata.xml                 Publication Date
# 8079      Dryad   Dryad  04198-metadata.xml      Related Resource Identifier
# 8080      Dryad   Dryad  04198-metadata.xml           Resource Creation Date
# 8081      Dryad   Dryad  04198-metadata.xml  Resource Creation/Revision Date
# 8082      Dryad   Dryad  04198-metadata.xml              Resource Identifier
# 8083      Dryad   Dryad  04198-metadata.xml              Resource Identifier
# 8084      Dryad   Dryad  04198-metadata.xml                 Resource Lineage
# 8085      Dryad   Dryad  04198-metadata.xml                   Resource Title
# 8086      Dryad   Dryad  04198-metadata.xml                    Resource Type
# 8087      Dryad   Dryad  04198-metadata.xml                           Rights
# 8088      Dryad   Dryad  04198-metadata.xml                 Taxonomic Extent
#
# [8089 rows x 4 columns]

# %%
CollectionConceptsDF.Concept.unique()
# Out:
# array(['Abstract', 'Author', 'Author / Originator', 'Embargo Date',
#        'Keyword', 'Lineage Statement', 'Parent Identifier',
#        'Publication Date', 'Related Resource Identifier',
#        'Resource Creation Date', 'Resource Creation/Revision Date',
#        'Resource Identifier', 'Resource Lineage', 'Resource Title',
#        'Resource Type', 'Rights', 'Spatial Extent', 'Taxonomic Extent',
#        'Temporal Extent', 'Distribution Format', 'Resource Format'], dtype=object)

# %%
def PropertyTypeTable(PropertyType):
    ProperTable = CollectionConceptsDF[CollectionConceptsDF.Concept == PropertyType]
    return ProperTable

# %%
PropertyTypeTable("Keyword")
# Out:
#      Collection Dialect              Record  Concept
# 10        Dryad   Dryad  00759-metadata.xml  Keyword
# 11        Dryad   Dryad  00759-metadata.xml  Keyword
# 12        Dryad   Dryad  00759-metadata.xml  Keyword
# 13        Dryad   Dryad  00759-metadata.xml  Keyword
# 14        Dryad   Dryad  00759-metadata.xml  Keyword
# 15        Dryad   Dryad  00759-metadata.xml  Keyword
# 16        Dryad   Dryad  00759-metadata.xml  Keyword
# 42        Dryad   Dryad  00760-metadata.xml  Keyword
# 43        Dryad   Dryad  00760-metadata.xml  Keyword
# 44        Dryad   Dryad  00760-metadata.xml  Keyword
# 70        Dryad   Dryad  00761-metadata.xml  Keyword
# 71        Dryad   Dryad  00761-metadata.xml  Keyword
# 72        Dryad   Dryad  00761-metadata.xml  Keyword
# 73        Dryad   Dryad  00761-metadata.xml  Keyword
# 74        Dryad   Dryad  00761-metadata.xml  Keyword
# 75        Dryad   Dryad  00761-metadata.xml  Keyword
# 76        Dryad   Dryad  00761-metadata.xml  Keyword
# 77        Dryad   Dryad  00761-metadata.xml  Keyword
# 78        Dryad   Dryad  00761-metadata.xml  Keyword
# 102       Dryad   Dryad  00762-metadata.xml  Keyword
# 103       Dryad   Dryad  00762-metadata.xml  Keyword
# 104       Dryad   Dryad  00762-metadata.xml  Keyword
# 105       Dryad   Dryad  00762-metadata.xml  Keyword
# 106       Dryad   Dryad  00762-metadata.xml  Keyword
# 107       Dryad   Dryad  00762-metadata.xml  Keyword
# 108       Dryad   Dryad  00762-metadata.xml  Keyword
# 135       Dryad   Dryad  00763-metadata.xml  Keyword
# 136       Dryad   Dryad  00763-metadata.xml  Keyword
# 137       Dryad   Dryad  00763-metadata.xml  Keyword
# 138       Dryad   Dryad  00763-metadata.xml  Keyword
# ...         ...     ...                 ...      ...
# 7909      Dryad   Dryad  01003-metadata.xml  Keyword
# 7910      Dryad   Dryad  01003-metadata.xml  Keyword
# 7911      Dryad   Dryad  01003-metadata.xml  Keyword
# 7933      Dryad   Dryad  01004-metadata.xml  Keyword
# 7934      Dryad   Dryad  01004-metadata.xml  Keyword
# 7935      Dryad   Dryad  01004-metadata.xml  Keyword
# 7936      Dryad   Dryad  01004-metadata.xml  Keyword
# 7937      Dryad   Dryad  01004-metadata.xml  Keyword
# 7938      Dryad   Dryad  01004-metadata.xml  Keyword
# 7963      Dryad   Dryad  01005-metadata.xml  Keyword
# 7964      Dryad   Dryad  01005-metadata.xml  Keyword
# 7965      Dryad   Dryad  01005-metadata.xml  Keyword
# 7966      Dryad   Dryad  01005-metadata.xml  Keyword
# 7967      Dryad   Dryad  01005-metadata.xml  Keyword
# 7968      Dryad   Dryad  01005-metadata.xml  Keyword
# 7969      Dryad   Dryad  01005-metadata.xml  Keyword
# 7992      Dryad   Dryad  01006-metadata.xml  Keyword
# 7993      Dryad   Dryad  01006-metadata.xml  Keyword
# 7994      Dryad   Dryad  01006-metadata.xml  Keyword
# 7995      Dryad   Dryad  01006-metadata.xml  Keyword
# 8018      Dryad   Dryad  01007-metadata.xml  Keyword
# 8019      Dryad   Dryad  01007-metadata.xml  Keyword
# 8020      Dryad   Dryad  01007-metadata.xml  Keyword
# 8021      Dryad   Dryad  01007-metadata.xml  Keyword
# 8022      Dryad   Dryad  01007-metadata.xml  Keyword
# 8046      Dryad   Dryad  01008-metadata.xml  Keyword
# 8047      Dryad   Dryad  01008-metadata.xml  Keyword
# 8048      Dryad   Dryad  01008-metadata.xml  Keyword
# 8049      Dryad   Dryad  01008-metadata.xml  Keyword
# 8050      Dryad   Dryad  01008-metadata.xml  Keyword
#
# [1150 rows x 4 columns]
